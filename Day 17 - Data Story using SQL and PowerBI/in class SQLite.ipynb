# %%
import numpy as np

# %% [markdown]
# - Data Storytelling
#
# - story telling - making a story - because

# %% [markdown]
# Run any language, we needed an IDE
#
# - https://sqliteonline.com/

# %%
-- query, database, table

# %% [markdown]
# In SQL, every row is called a record.
#
# - Create a databases
# - create tables
# - query databases and tables
# - create views, view a part of the database

# %% [markdown]
# 1. Query a database
#     - can manipulate data within a database
#     - create, or retrieve data from a database
#
# 2. CRUD operations on Records
#     - Create
#     - Read
#     - Update
#     - Delete

# %% [markdown]
# SELECT * FROM Depatments

# %% [markdown]
# - SELECT - extract data from a databse
# - INSERT INTO

# %% [markdown]
# - Run SQL in  python version, called SQLite

# %% [markdown]
# CREATE TABLE Department(  -- create table -> create a new table  -- Specify name
#   id	  INT PRIMARY KEY,  -- created a new column, assigned INTEGER data type to it, -- added a constraint (rule or property)
#   name	  VARCHAR(50)
#   )

# %%
pip install sqlite3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
import sqlite3 as sql

# %%
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 connection.commit()
#
# NameError: name 'connection' is not defined
