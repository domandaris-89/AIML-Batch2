# %%
list2 = [3,4,5, 'Idrees', 4.5, [3, ['a','b'],5]]

list2[5][1][0]
# Out:
# 'a'

# %%
vector1 = [10,4,10]

vector2 = [20,4,10]

vector3 = [30,4,10]

sum(vector1)
len(vector1)
# Out:
# 3

# %%
import numpy as np

arr = np.array(vector1)
arr

arr.max()
arr.min()
arr.mean()
arr.var()
arr.std()
# Out:
# np.float64(2.8284271247461903)

# %%
matrix = [vector1,vector2] # row , colummn

matrix


# [2,4,10] as a result
# 2 as a result
# Out:
# [[10, 4, 10], [20, 4, 10]]

# %%
matrix[1]
# Out:
# [20, 4, 10]

# %%
matrix[1][0]
# Out:
# 20

# %%
matrix = [[10,4,10],
          [20,4,10],
          [30,4,10]]

matrixarr = np.array(matrix)

# %%
type(matrixarr)

matrixarr.ndim # dimension
matrixarr.shape # how many rows and columns
# Out:
# (3, 3)

# %%
matrixarr[1][2]
# Out:
# np.int64(10)

# %%
matrixarr * 2 # scaler multiplication

# scaler operation with arrays
# Out:
# array([[20,  8, 20],
#        [40,  8, 20],
#        [60,  8, 20]])

# %%
# broadcasting

matrixarr + 100
# Out:
# array([[110, 104, 110],
#        [120, 104, 110],
#        [130, 104, 110]])

# %%
variance = np.array([145325, 423542, 24355, 3523456])
n = np.array([145, 542, 355, 3456])

# %%
((variance)**0.5)  .round(2)
# Out:
# array([ 381.22,  650.8 ,  156.06, 1877.09])

# %%
covariance = np.array([145325, 423542])

n = np.array([145, 542, 355, 3456])

stdx , stdy = np.array([ 381.22, 650.8])

stdx
stdy

r = covariance

# %%
x = np.array([[1,4,1],
              [2,5,2]])
 
x = np.array([[1,4,1],
              [2,5,2]])
 
w = np.array([10,10,10])
 
matmultiply_xw = np.dot(x,w)
matmultiply_xw
# Out:
# array([60, 90])

# %%
w2 = np.array([[10,2,3],
              [10,2,3],
              [10,2,3]])

matmultiply_xw2 = np.dot(x,w2)
matmultiply_xw2
# Out:
# array([[60, 12, 18],
#        [90, 18, 27]])

# %%
A = np.array(
    [[5,5,5],
     [2,2,2],
     [5,5,5]]
)

B = np.array(
    [[3,3,3],
     [3,3,3],
     [3,3,3]]
)

print('Matrix Multiplication: \n',A @ B, '\n')
print('Array Multiplication: \n',A * B)

print('_____________________ B x A')

print('Matrix Multiplication: \n',B @ A, '\n')
print('Array Multiplication: \n',B * A)
# matrix multiplication is not commutative
# Out:
# Matrix Multiplication:
#  [[45 45 45]
#  [18 18 18]
#  [45 45 45]]
#
# Array Multiplication:
#  [[15 15 15]
#  [ 6  6  6]
#  [15 15 15]]
# _____________________ B x A
# Matrix Multiplication:
#  [[36 36 36]
#  [36 36 36]
#  [36 36 36]]
#
# Array Multiplication:
#  [[15 15 15]
#  [ 6  6  6]
#  [15 15 15]]

# %% [markdown]
# - arrays are faster, huge data,
# - list arrays for 100K numbers
