# %% [markdown]
# Distribution
#
# - how the frequency of something is distributed.
#
# - That if you take a **sample size** of 100 people:
#
# - I want to know how tall the people of Phile are, ages between 18 to 45
#
# 7 feet
#
# 5 feet
#
# 3 feet
#
# - Selecting a sample size: 5k  -> 100
# - measuring
# - rows of data: 100 rows of data
# - name, age, height, gender, ethnicity

# %% [markdown]
# ## AI ETHICS
#
# - data privacy - if the data is safe with the researchers - anonimity
# - data transparency - how are you using the data

# %%
data = {
    'name': ['idrees','hazirah','atirah','mel','nazri','ibrahim','amin'],
    'age': [29,24,25,25,25,25,25],
    'height':[185, 152, 163, 162,164,168,168],
    'gender':['m','f','f','f','m','m','m'],
    'ethnicity':['kashmiri','malay','malay','malay','malay','malay','malay']
}

import pandas as pd
df=pd.DataFrame(data)
df.head(7)
# Out:
#       name  age  height gender ethnicity
# 0   idrees   29     185      m  kashmiri
# 1  hazirah   24     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay

# %%
import seaborn as sns 
sns.histplot(data = df, x = 'height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
malay = df[ df['ethnicity'] == 'malay']
print(malay)

female = df[ df['gender']=='f']
print(female)

malayOver21 = df[ (df['ethnicity']=='malay') & (df['age'] >21)]
malayOver21

# & and
# | or
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay
#       name  age  height gender ethnicity
# 1  hazirah   24     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay

# %%
sns.histplot(data = df, x = 'height', bins=20)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
tipsdf = sns.load_dataset('tips')
tipsdf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# create these data frames
#1. only male
#2. tips above 6 dollars
#3. smokers dining (having dinner) on Sunday

male = tipsdf[ tipsdf['sex'] == 'Male']
print(male)

tips = tipsdf[ tipsdf['tip'] > 6]
print(tips)

smokerSunDinner = tipsdf[ (tipsdf['smoker'] == 'Yes') & (tipsdf['time'] == 'Dinner') & (tipsdf['day'] == 'Sun')]
print(smokerSunDinner)

#malayOver21 = df[ (df['ethnicity']=='malay') & (df['age'] >21)]
#malayOver21
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
#      total_bill   tip     sex smoker  day    time  size
# 164       17.51  3.00  Female    Yes  Sun  Dinner     2
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2
# 174       16.82  4.00    Male    Yes  Sun  Dinner     2
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2
# 176       17.89  2.00    Male    Yes  Sun  Dinner     2
# 177       14.48  2.00    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2

# %% [markdown]
# - Checking the distribution of data in our dataset
#
# - or how many data points, there are for male and female?
# - how many for each day of the week?
# - how many for each ethnicity?

# %% [markdown]
# - checking if we can rely on data
# - looking at sample size to check for anything out of ordinary
#
# we study distributions in ML, because class distributions influence the outputs of AI Models
#
# - very simple example : Case study:
# - a company in US Security
# - they wanted to create a tool, that would screen criminals?
# - just by looking at face that somebody is a criminal?
#
# - there should be a database. there should data.
#
# - more examples of black people, in their data base along with the crimes they had comitted
# - vs the white or hispanic examples
#
#
# - **1000** african american original cases
# - **100** white hispanic
#
# - data to an AI Model, will always be correct when labelling a african american as a criminal?
#
# - it lead to false arrests
#
# **class imbalance**
#
# - if there is more data related to one class compared to the other
#
#     - eg. Male female  =  100:70
#     - smoker nonsmoker
#     - ethnicity of two races of people
#     -
