# %% [markdown]
# - Data Visualisation is a small part of the overall EDA process
#
# - EDA = Exploratory Data Analysis
#
# - Data Anlysts --->
#     - tools like Power BI
#     - Tableau
#     - Large volumes of data - large quantity
#         -300 rows is not large
#         10k around data fair amount of data
#         400k rows of data
#
# - To be able to find data - data sources
# - Import that data into your python files (1)
# - should be able to analyse it (2)
#     - by using visualization tools we learnt
#     -matplotlib and seaborn

# %% [markdown]
# 1. Find data related to the titanic ship
#     -download and  import to nbs
#     -make some visualisations
#     -and finally, write 4 lines about the data (give some information about the data that is not easily observable-make some judgement/inferences)

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic=titanic.dropna()

# %%
titanic['age'] = titanic['age'].astype(int)
titanic
# Out:
# C:\Users\NEC\AppData\Local\Temp\ipykernel_16056\1824805563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['age'] = titanic['age'].astype(int)
#      survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 1           1       1  female   38      1      0  71.2833        C  First
# 3           1       1  female   35      1      0  53.1000        S  First
# 6           0       1    male   54      0      0  51.8625        S  First
# 10          1       3  female    4      1      1  16.7000        S  Third
# 11          1       1  female   58      0      0  26.5500        S  First
# ..        ...     ...     ...  ...    ...    ...      ...      ...    ...
# ...

# %%
titanic['fare'] = titanic['fare'].round(2)
titanic
# Out:
# C:\Users\NEC\AppData\Local\Temp\ipykernel_16056\4195265605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['fare'] = titanic['fare'].round(2)
#      survived  pclass     sex  age  sibsp  parch   fare embarked  class  \
# 1           1       1  female   38      1      0  71.28        C  First
# 3           1       1  female   35      1      0  53.10        S  First
# 6           0       1    male   54      0      0  51.86        S  First
# 10          1       3  female    4      1      1  16.70        S  Third
# 11          1       1  female   58      0      0  26.55        S  First
# ..        ...     ...     ...  ...    ...    ...    ...      ...    ...
# ...

# %% [markdown]
# 1.Ticket fare does not represent an individual's payment, maybe the total cost for a group or family
#
# 2.Women were much more likely to survive than men. The rule to save "women and children first" is conducted.
#
# 3.Wealthier passengers had the best chance of survival. People in first class were more likely to get on a lifeboat than those in second or third class.
#
# 4. Young children survived more than adults. Very young babies had the best chance of being saved.

# %% [markdown]
# - Finding the data (first challenge!!!!)
#
# ### Data Sources
#
# - **Primary**
#     -data that we collect ourselves
#     -problem - people you meet?
#     -sensor data
#         -sensors sense environment data -
#             - proximity sensors - if you are close to the door
#             -temperature sensor
#
#     -you have to invest time, effort into this
#     -need infrastructure
#     -even money
#     -researchers, people who have some incentive like
#
# - **Secondary** - Rely on this a lot
#     - data that you get from someone else
#     - computer, looking for data and you download it
#
#
#     - Kaggle
#     - Gov datasets
#     - github
#     - uci

# %% [markdown]
# **What the problem is:**
# Public Transport Usage or Bus Arrival Times
# **Who the solution is for:**
# Bus users, transportation companies,students, office workers
# **Where is the problem occuring:**
# Bus routes in major Malaysian cities
# **Why is it worth solving**
# Helps reduce waiting time and improves commuter planning

# %%
import numpy as np

# %%
import pandas as pd

# %%
ptm = pd.read_csv('ridership_headline.csv')
ptm
# Out:
#             date   bus_rkl  bus_rkn  bus_rpn  rail_lrt_ampang  \
# 0     2019-01-01       NaN      NaN      NaN           113357
# 1     2019-01-02       NaN      NaN      NaN           182715
# 2     2019-01-03       NaN      NaN      NaN           187904
# 3     2019-01-04       NaN      NaN      NaN           198420
# 4     2019-01-05       NaN      NaN      NaN           120773
# ...          ...       ...      ...      ...              ...
# 2491  2025-10-27  217637.0   2197.0  49849.0           188362
# 2492  2025-10-28  226834.0   2191.0  50391.0           191938
# 2493  2025-10-29  246232.0   2020.0  49316.0           218432
# 2494  2025-10-30  243114.0   2092.0  46269.0           217969
# 2495  2025-10-31  239690.0   2191.0  51477.0           225355
#
#       rail_mrt_kajang  rail_lrt_kj  rail_monorail  rail_mrt_pjy  rail_ets  \
# 0              114173       139634          35804           NaN       NaN
# ...

# %%
ptm=ptm.dropna()
ptm
# Out:
#             date   bus_rkl  bus_rkn  bus_rpn  rail_lrt_ampang  \
# 1713  2023-09-10  142452.0   2582.0  39384.0           105562
# 1714  2023-09-11  205586.0   2800.0  39507.0           157865
# 1715  2023-09-12  213383.0   2617.0  40971.0           162603
# 1716  2023-09-13  213494.0   2779.0  40401.0           164264
# 1717  2023-09-14  208610.0   2727.0  39361.0           161769
# ...          ...       ...      ...      ...              ...
# 2491  2025-10-27  217637.0   2197.0  49849.0           188362
# 2492  2025-10-28  226834.0   2191.0  50391.0           191938
# 2493  2025-10-29  246232.0   2020.0  49316.0           218432
# 2494  2025-10-30  243114.0   2092.0  46269.0           217969
# 2495  2025-10-31  239690.0   2191.0  51477.0           225355
#
#       rail_mrt_kajang  rail_lrt_kj  rail_monorail  rail_mrt_pjy  rail_ets  \
# 1713           136816       130885          48423       60038.0   11925.0
# ...

# %%
ptm.shape
# Out:
# (783, 14)

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = df.rename(columns={'sepal_length':'d','sepal_width':'d1','petal_length':'f','petal_width':'f1','species':'a'})
df.head()
# Out:
#      d   d1    f   f1       a
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
#  This is how you target a row
df.loc[1] # row

df['a'][8] # goes first to column, row

df

df['a'] # direct access to column
# Out:
# d        4.9
# d1       3.0
# f        1.4
# f1       0.2
# a     setosa
# Name: 1, dtype: object

# %%
df.head(2)
# Out:
#      d   d1    f   f1       a
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa

# %%
columns = ['p_len','p_wid','s_len','s_wid','species']

iris = pd.read_csv('iris.csv', header = None, skiprows=1, names= columns)
iris.head(2)
# Out:
#    p_len  p_wid  s_len  s_wid species
# 0    5.1    3.5    1.4    0.2  setosa
# 1    4.9    3.0    1.4    0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)
